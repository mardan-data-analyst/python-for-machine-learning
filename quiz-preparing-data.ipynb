# %%
fruits = "A,B,C,D,E,F,G,H".split(" ")
fruits
# Out:
# ['A,B,C,D,E,F,G,H']

# %%
fruits.sprit(" ")

# %%
print("abcdefcdghcd".split("c"))
# Out:
# ['ab', 'def', 'dgh', 'd']

# %%
line = "line line"
print(line.capitalize())
# Out:
# Line line

# %%
string1 =  "Hello AI World"

# %%
words1 = string1.split("")
words1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-6a28a313d88d> in <module>()
# ----> 1 words1 = string1.split("")
#       2 words1
#
# ValueError: empty separator

# %%
words2 = string1.split()
words2
# Out:
# ['Hello', 'AI', 'World']

# %%
list1 = ["A", "B", "C", "D", "F"]
list2 = [1, 2, 3, 4, 5, 6, 7, 8, 9]
dictionary3 = dict(zip(list1, list2))
dictionary3
# Out:
# {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'F': 5}
