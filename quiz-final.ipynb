# %%
string =  "Hello AI World"

# %%
string.split("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d84b11286800> in <module>()
# ----> 1 string.split("")
#
# ValueError: empty separator
