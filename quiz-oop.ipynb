# %%
class favLanguage():
  def printLine(self, language = "Python"):
    print(language)

# %%
myObject = favLanguage()
myObject.printLine("Java")
# Out:
# Java

# %%
class Sales:
  def __init__(self, id):
    self.id = id
    id = 100

# %%
val = Sales(123)
print(val.id)
# Out:
# 123
