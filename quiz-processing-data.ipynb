# %%
import numpy as np

# %%
array1 = np.array([1, 4, 8, 6, 2])
array2 = np.array([[11, 44, 88, 66, 22],
                   [22, 10, 47, 60, 5]])

# %%
array3 = np.array([array1.sum(), array2.ndim, array2.size, array1.argmax(), array2.argmin()])
array3
# Out:
# array([21,  2, 10,  2,  9])

# %%
names = ["A", "B", "C"]
revenues = [500, 1000, 1500]

names_array = np.array([names])
data = np.concatenate((names_array, revenues), axis=0)
print(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-0e651eaf0ef2> in <module>()
#       3
#       4 names_array = np.array([names])
# ----> 5 data = np.concatenate((names_array, revenues), axis=0)
#       6 print(data)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)
